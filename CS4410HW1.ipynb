# %% [markdown]
# <a href="https://colab.research.google.com/github/marcusslongweek/Homework/blob/main/CS4410HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Ezego-Capo/Diamond_dataset/refs/heads/main/diamonds.csv'
diamonds = pd.read_csv(url, index_col=0)

# %%
diamonds.head(7)
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 0.24   Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 0.24   Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47

# %%
diamonds.head(7)
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 0.24   Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 0.24   Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47

# %%
diamonds.describe()
# Out:
#               depth         table         price             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean      61.749405     57.457184   3932.799722      5.731157      5.734526
# std        1.432621      2.234491   3989.439738      1.121761      1.142135
# min       43.000000     43.000000    326.000000      0.000000      0.000000
# 25%       61.000000     56.000000    950.000000      4.710000      4.720000
# 50%       61.800000     57.000000   2401.000000      5.700000      5.710000
# 75%       62.500000     59.000000   5324.250000      6.540000      6.540000
# max       79.000000     95.000000  18823.000000     10.740000     58.900000
#
#                   z
# count  53940.000000
# mean       3.538734
# std        0.705699
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %%
diamonds[['cut', 'color', 'clarity']].describe()
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
display(diamonds['cut'].unique())
display(diamonds['color'].unique())
display(diamonds['clarity'].unique())
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
# %matplotlib inline

# %%
diamonds.hist()
# Out:
# array([[<Axes: title={'center': 'depth'}>,
#         <Axes: title={'center': 'table'}>],
#        [<Axes: title={'center': 'price'}>, <Axes: title={'center': 'x'}>],
#        [<Axes: title={'center': 'y'}>, <Axes: title={'center': 'z'}>]],
#       dtype=object)
